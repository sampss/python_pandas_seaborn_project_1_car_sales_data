# %% [markdown]
# ### **Data Project Rubric:**  **Data Analysis with Python (Pandas & Matplotlib)**
#
# #### **1\. Project Overview**
# * **Objective**: Analyze the given car sales data.  From the available sales data determine who the 5 best sales people were overall, who the 5 best sales people were seasonaly, what season was best for sales.
#
# * **Data Source**: This is sales data is from https://www.kaggle.com/datasets/suraj520/car-sales-data and is data regarding car sales over the course of a year.  Within the dataset I will be able to use the name, volume and sales value to determing which salesperson within this set sold the most in value and the highest quantity of cars.
#
# #### **2\. Data Collection and Loading**
# * **Load Data**: Data was in csv format.
# * **Initial Check**: There is no missing data.
#
# | Date       | Salesperson      | Customer Name | Car Make | Car Model | Car Year | Sale Price  | Commission Rate | Commission Earned |
# |------------|------------------|---------------|----------|-----------|----------|-------------|-----------------|-------------------|
# | 2022-08-01 | Monica Moore MD  | Mary Butler   | Nissan   | Altima    | 2018     | $15,983     | $0.07           | $1,126.73         |
#
# * **Selection Options**:
#     * The only unusable column in this dataset is customer name therefore I dropped it.
#
# #### **3\. Data Cleaning and Preparation**
#
# * **Initially Inpect Dataframe**: Inspect head of dataframe to determine discrepencies.
# * **Handle Missing Values**: No missing values in the dataset.
#     * Dopped one column as it posed no real value to the dataset. (Customer Name)
# * **Pandas options set**:
#     * Display columns without wrapping
# * **Data Type Adjustments**:
#     * Set sale price from int64 to float.
#     * Set Date in date format.
#     * Set Car year in date format year only.
#     * Noted Make/Model discrepancy.  Nissan did not make an F-150. Corrected these types discrepancies.
# * **Feature Engineering**:
#     * Created a season column, can be used to see vehicle sells better in spring, summer, fall or winter.
#
# | Spring            | Summer          | Fall           | Winter       |
# |-------------------|-----------------|----------------|--------------|
# | March, April, May | June, July, Aug | Sept, Oct, Nov |Dec, Jan, Feb |
#
#
# #### **4\. Exploratory Data Analysis (EDA)**</br>
# * **Descriptive Statistics**:
#     * Included dataframe description for objects and numeric data types.
#
# **Table: non numeric data**
#
# | Statistic  | Date           | Salesperson    | Car Make  | Car Model | Season    |
# |------------|----------------|----------------|-----------|-----------|-----------|
# | count      | 2,500,000      | 2,500,000      | 2,500,000 | 2,500,000 | 2,500,000 |
# | unique     | 366            | 518,657        | 5         | 5         | 4         |
# | top        | 22-12-24       | Michael Smith  | Chevrolet | Silverado | Spring    |
# | freq       | 7,144          | 1,229          | 500,842   | 500,842   | 634,282   |
#
# **Table: Numeric Data**
#
# | Statistic  | Sale Price     | Commission Rate | Commission Earned |
# |------------|----------------|-----------------|-------------------|
# | count      | $2,500,000.00  | $2,500,000.00   | $2,500,000.00     |
# | mean       | $30,012.18     | $0.10           | $3,001.01         |
# | std        | $11,545.14     | $0.03           | $1,481.47         |
# | min        | $10,000.00     | $0.05           | $501.34           |
# | 25%        | $20,019.00     | $0.07           | $1,821.71         |
# | 50%        | $30,006.00     | $0.10           | $2,741.91         |
# | 75%        | $40,022.00     | $0.13           | $3,978.14         |
# | max        | $50,000.00     | $0.15           | $7,494.53         |
#
# * **Top 5 sales reps in order**:
#     * Showed, grouped by top 5 sales reps in order by 'Number Sales', 'Total Sales', 'Total Commission'.
#         * added times reps name appeard, aggregated: number of sales, total sales, total commission
#     * Showed sideways bar chart from smallest to largest Y axis is sales person, x axis is # sales.
#     * Showed sideways bar chart from smallest to largest Y axis is sales person, x axis is total sales.
#         * had to use matplotlib FuncFormatter for better presentation. set Y axis to dollar amount, labeled X,Y axises and Titled chart.
#
# #### **5\. Analysis and Insights**
# * **Findings**: I was able to discover the top sales persons within this data set.  No Specific patterns have been discovered at this point.
#     * Where I added the season feature I intend to explore vehicle model sales by season, sales person productivity by season.
#
# * **Supporting Data**:
#     * Findings show that Michael Smith was the lead salesman by a broad margin.
#
# Spring
# | Michael Smith     | Michael Johnson     | David Smith     | Robert Smith    |
# |-------------------|---------------------|-----------------|-----------------|
# | 9,484,498.00      | $7,621,293.00       | $6,583,567.00   | $6,045,094.00   |
#
# Winter
# | Michael Smith     | Michael Johnson     | David Smith     | Robert Smith    |
# |-------------------|---------------------|-----------------|-----------------|
# | 9,190,907.00      | $6,265,038.00       | $6,092,166.00   | $6,062,310.00   |
#
# #### **6\. Conclusion and Recommendations**
# * **Summarize**:
#     * Michael Smith was able to outsell others by a large margin each season
#     * This might be an indicator that sales could be improved, recommended to research Michael's sales tactics and try to replicate them.
#     * It also may be beneficial to have Michael assist with training the other sales reps.
#
# * **Recommendations**: Based on findings, suggest actions or further analysis.
#     * Given the sales date for each sale, I was able to engineer another column for Season.
#     * Utilizing the season column it could be helpful to see what cars sold better per season.
#     * It may also be possible to find correlation between the value of sales and the season.
#
# ### **Optional Advanced Section (Bonus)**
#
# * **Advanced EDA**: Used a pair plot to view how seasons effected some sales.
#     * The cars sold progressively got older as the year progressed.
#     * People spent a lot more per auto purchase in the summer.
#     * During summer months commission people with higher commission rates sold more leading to significantly higher payout for commission.
#
#
# * **Dashboards**: Create a simple dashboard with Matplotlib or extend to Dash/Streamlit.
